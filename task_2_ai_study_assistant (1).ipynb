# %%
# !pip install -q gradio google-generativeai python-dotenv

# %%
import gradio as gr
import google.generativeai as genai
from google.colab import userdata

API_KEY = userdata.get("GOOGLE_API_KEY")

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("gemini-1.5-flash")

print("Gemini Model Loaded Successfully!")
# Out:
# Gemini Model Loaded Successfully!

# %%
def study_assistant(question):
    response = model.generate_content(
        f"You are an AI Study Assistant. Answer this question in a simple and easy-to-understand way:\n\n{question}"
    )
    return response.text

# %%
import gradio as gr

def predict(text):
    # yahan tumhara model/function hona chahiye
    return "Answer: " + text

gr.Interface(fn=predict, inputs="text", outputs="text").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a0fd91115eca58ffc6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a0fd91115eca58ffc6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
